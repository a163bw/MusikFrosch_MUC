# %%
import pandas as pd

# %%
df = pd.read_csv('df_10fin.csv')

# %%
display(df)
# Out:
#      level_0  index                                                URL  \
# 0          0    0.0  https://www.muffatwerk.de/de/events/view/6826/...
# 1          1    1.0  https://www.muffatwerk.de/de/events/view/6874/...
# 2         81    7.0                  https://milla-club.de/jazz-jam-7/
# 3         80    6.0              https://milla-club.de/bernd-begemann/
# 4         79    5.0                https://milla-club.de/luca-vasta-2/
# ..       ...    ...                                                ...
# 913      913  838.0           https://heppel-ettlich.de/openstage.html
# 914      914  839.0           https://heppel-ettlich.de/openstage.html
# 915      915  840.0           https://heppel-ettlich.de/openstage.html
# 916      916  841.0  https://www.feierwerk.de/konzert-kulturprogram...
# 917      917  842.0  https://www.feierwerk.de/konzert-kulturprogram...
#
#                     Date                                              Event  \
# ...
